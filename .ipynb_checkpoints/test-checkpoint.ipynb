# %%
from wind_action_secc4 import *
# Out:
# C:\Users\cfcpc2\Documents\GitHub\GitHub_CFC\Wind_Action\wind_action_secc4.py:225: RuntimeWarning: divide by zero encountered in log
#   funclist = [k_r() * np.log(z / z_0), k_r() * np.log(z_min / z_0)]

# %%
v_b_func()
# Out:
# v_b = c_dir⋅cₛₑₐₛₒₙ⋅v_b0

# %%
N(c_r_func(z=1, z_min=1, z_max=20, z_0=z_0, k_r=k_r, UE=False))
# Out:
# cᵣ(z) = 5.80964286535568⋅kᵣ

# %%
v_m_func()
# Out:
#         ⎛⎧       ⎛z ⎞                          ⎞
#         ⎜⎪ kᵣ⋅log⎜──⎟   for zₘₐₓ ≥ z ∧ zₘᵢₙ ≤ z⎟
#         ⎜⎪       ⎝z₀⎠                          ⎟
# vₘ(z) = ⎜⎨                                     ⎟⋅c₀⋅v_b
#         ⎜⎪      ⎛zₘᵢₙ⎞                         ⎟
#         ⎜⎪kᵣ⋅log⎜────⎟       for zₘᵢₙ ≥ z      ⎟
#         ⎝⎩      ⎝ z₀ ⎠                         ⎠

# %%
v_m_func(z=5,c_0=1,v_b=28).subs(z_0,1.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 v_m_func(z=5,c_0=1,v_b=28).subs(z_0=1)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\sympy\core\basic.py:972, in Basic.subs(self, *args, **kwargs)
#     970     sequence = [args]
#     971 else:
# --> 972     raise ValueError("subs accepts either 1 or 2 arguments")
#     974 def sympify_old(old):
#     975     if isinstance(old, str):
#     976         # Use Symbol rather than parse_expr for old
#
# ValueError: subs accepts either 1 or 2 arguments

# %%
c_r_func?
# Out:
# Signature: c_r_func(z=z, z_min=z_min, z_max=z_max, z_0=z_0, k_r=k_r, UE=False)
# Docstring: <no docstring>
# File:      c:\users\cfcpc2\documents\github\github_cfc\wind_action\wind_action_secc4.py
# Type:      function

# %%
v_m()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 v_m()
#
# TypeError: 'v_m' object is not callable
