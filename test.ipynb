# %%
from wind_action_secc4 import *
# Out:
# C:\Users\cfcpc2\Documents\GitHub\GitHub_CFC\Wind_Action\wind_action_secc4.py:226: RuntimeWarning: divide by zero encountered in log
#   funclist = [k_r() * np.log(z / z_0), k_r() * np.log(z_min / z_0)]

# %%
v_b_func()
# Out:
# v_b = c_dir⋅cₛₑₐₛₒₙ⋅v_b0

# %%
N(c_r_func(z=1, z_min=1, z_max=20, z_0=z_0, k_r=k_r, UE=False))
# Out:
# cᵣ(z) = 5.80964286535568⋅kᵣ

# %%
v_m_func()
# Out:
# vₘ(z) = cᵣ(z)⋅c₀⋅v_b

# %%
v_m_func(z=5,c_0=1,v_b=28).subs(k_r,1.0).subs(z_min,1.0)
# Out:
# vₘ(z) = cᵣ(z)⋅1⋅28

# %%
v_m_func(z=5,c_0=1,v_b=28,c_r=c_r_func(z=1, z_min=1, z_max=20, z_0=z_0, k_r=k_r, UE=False).rhs)
# Out:
# vₘ(z) = kᵣ⋅log(3.3e+2)⋅1⋅28

# %%
v_m()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 v_m()
#
# TypeError: 'v_m' object is not callable
